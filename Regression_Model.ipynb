# %% [markdown]
# <a href="https://colab.research.google.com/github/shashankbhagat/House-Price-Prediction/blob/master/Regression_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Develop the Regression model**

# %%
import pandas as pd
import numpy as np

from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
pd.set_option('display.max_columns',None)

# %%
train=pd.read_csv('Train_final.csv')
train.head()
# Out:
#    MSZoning  LotShape  BldgType  OverallQual  YearRemodAdd  ExterQual  \
# 0       0.5       1.0       0.0     0.666667      0.098361   0.333333
# 1       0.5       1.0       0.0     0.555556      0.524590   1.000000
# 2       0.5       0.0       0.0     0.666667      0.114754   0.333333
# 3       0.5       0.0       0.0     0.666667      0.606557   1.000000
# 4       0.5       0.0       0.0     0.777778      0.147541   0.333333
#
#    BsmtQual  BsmtExposure  BsmtFinType1  HeatingQC  CentralAir  1stFlrSF  \
# 0       0.5          1.00      0.333333        0.0         1.0  0.356155
# 1       0.5          0.25      0.000000        0.0         1.0  0.503056
# 2       0.5          0.75      0.333333        0.0         1.0  0.383441
# 3       1.0          1.00      0.000000        0.5         1.0  0.399941
# 4       0.5          0.00      0.333333        0.0         1.0  0.466237
#
#    GrLivArea  BsmtFullBath  KitchenQual  Fireplaces  GarageType  GarageFinish  \
# ...

# %%
selected_features=pd.read_csv('selected_features.csv')
selected_features=selected_features.columns

trainX=train[selected_features]
trainY=train['SalePrice']
trainX.head()
# Out:
#    MSZoning  LotShape  BldgType  OverallQual  YearRemodAdd  ExterQual  \
# 0       0.5       1.0       0.0     0.666667      0.098361   0.333333
# 1       0.5       1.0       0.0     0.555556      0.524590   1.000000
# 2       0.5       0.0       0.0     0.666667      0.114754   0.333333
# 3       0.5       0.0       0.0     0.666667      0.606557   1.000000
# 4       0.5       0.0       0.0     0.777778      0.147541   0.333333
#
#    BsmtQual  BsmtExposure  BsmtFinType1  HeatingQC  CentralAir  1stFlrSF  \
# 0       0.5          1.00      0.333333        0.0         1.0  0.356155
# 1       0.5          0.25      0.000000        0.0         1.0  0.503056
# 2       0.5          0.75      0.333333        0.0         1.0  0.383441
# 3       1.0          1.00      0.000000        0.5         1.0  0.399941
# 4       0.5          0.00      0.333333        0.0         1.0  0.466237
#
#    GrLivArea  BsmtFullBath  KitchenQual  Fireplaces  GarageType  GarageFinish  \
# ...

# %% [markdown]
# **Using the Decision Tree Regressor as the regression algorithm**

# %%
model=DecisionTreeRegressor()
model.fit(trainX,trainY)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
## Predicting the training data to check training data error using Mean Squared Error
result=model.predict(trainX)
print('Training error:{}'.format(mean_squared_error(trainY,result)))
# Out:
# Training error:2.0596406030265123e-06

# %%
## Bring in test data and perform prediction of SalePrice on it
testData=pd.read_csv('Test_final.csv')
result=model.predict(testData)

# %%
## Convert the SalePrice usinf exponential function as it 
## would generate result according to log normal function.
Predicted_SalePrice=np.exp(result)
Predicted_SalePrice
# Out:
# array([ 62383., 148000., 180000., ..., 127000.,  97000., 228500.])

# %%
## Concat the results of Predicted SalePrice with original test data csv
testData_unformatted=pd.read_csv('test.csv')
testData_prediction=pd.concat([testData_unformatted,pd.DataFrame(data=Predicted_SalePrice,columns=['SalePrice'])],axis=1)
testData_prediction.head(50)
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1   1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2   1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3   1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4   1465         120       RL         43.0     5005   Pave   NaN      IR1
# 5   1466          60       RL         75.0    10000   Pave   NaN      IR1
# 6   1467          20       RL          NaN     7980   Pave   NaN      IR1
# 7   1468          60       RL         63.0     8402   Pave   NaN      IR1
# 8   1469          20       RL         85.0    10176   Pave   NaN      Reg
# 9   1470          20       RL         70.0     8400   Pave   NaN      Reg
# 10  1471         120       RH         26.0     5858   Pave   NaN      IR1
# 11  1472         160       RM         21.0     1680   Pave   NaN      Reg
# ...

# %%
testData_prediction.to_csv('TestData_Prediction.csv',index=False)
